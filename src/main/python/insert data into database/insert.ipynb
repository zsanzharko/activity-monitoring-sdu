# %%
import pandas as pd
import mysql.connector
from mysql.connector import Error
from mysql.connector import errorcode

# %%
#### CONFIG

# %%
HOST = '195.49.215.33'
DATABASE = 'ams'
USER = 'student'
PASSWORD = 'sdu_student'

# %%
try:
    connection = mysql.connector.connect(host=HOST, database=DATABASE, user=USER, password=PASSWORD)
    if connection.is_connected():
        cursor = connection.cursor()
        cursor.execute('select database();')
        record = cursor.fetchone()
        cursor.close()
        connection.close()
        print('Connected to {} database'.format(record[0]))
except Error as e:
    print('Error while connecting to MySQL', e)

# %% [markdown]
# #### INSERT FUNCTION

# %%
def insert(df, tname):
    for index, row in df.iterrows():
        command = f"insert into {tname} values("
        for cell in row:
            if type(cell) == str:
                cell = "'" + cell.replace('\'', '') + "'"
            command += str(cell) + ", "
        command = command[:-2] + ");"
        try:
            connection = mysql.connector.connect(host=HOST, database=DATABASE, user=USER, password=PASSWORD)
            if connection.is_connected():
                cursor = connection.cursor()
                try:
                    cursor.execute(command)
                except Error as err:
                    print(err.msg)
                else:
                    print("inserted.")
                cursor.close()
                connection.commit()
                connection.close()
        except Error as e:
            print('Error while connecting to MySQL', e)

# %% [markdown]
# #### INSERT DATE INTO PROJECTS TABLE

# %%
projects = pd.read_csv('data/projects.csv')

# %%
insert(projects, 'projects')

# %% [markdown]
# #### INSERT DATE INTO USERS TABLE

# %%
users = pd.read_csv('data/users.csv')

# %%
insert(users, 'users')

# %% [markdown]
# #### INSERT DATE INTO ACTIVITIES TABLE

# %%
activities = pd.read_csv('data/activities.csv')

# %%
insert(activities, 'activities')
# Out:
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# ...

# %% [markdown]
# #### INSERT DATE INTO CONSIST TABLE

# %%
consist = pd.read_csv('data/consist.csv')

# %%
insert(consist, 'consist')
# Out:
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# inserted.
# ...

# %% [markdown]
# #### INSERT DATE INTO MANAGE TABLE

# %%
manage = pd.read_csv('data/manage.csv')

# %%
insert(manage, 'manage')

# %% [markdown]
# #### INSERT DATE INTO ROLE TABLE

# %%
role = pd.read_csv('data/role.csv')

# %%
insert(role, 'role')

# %% [markdown]
# #### INSERT DATE INTO REPORT TABLE

# %%
report = pd.read_csv('data/report.csv')

# %%
insert(report, 'report')
